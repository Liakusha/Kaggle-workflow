# %%
import random
import os

def seed_everything(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)

# %%
from pathlib import Path
DATA_PATH = Path("C:/ML_Projects/kaggle-workflow/data/")
OUTPUT_PATH = Path("C:/ML_Projects/kaggle-workflow/output/")

# General settings
SEED = 42
N_FOLDS = 5

# Metric choice placeholder
#Adjust depending on the competition
METRIC = "auc"

# %%
import pandas as pd 
import numpy as np
#Load Data
train = pd.read_csv(DATA_PATH / "Diabetes Prediction Challenge" / "train.csv")
test = pd.read_csv(DATA_PATH / "Diabetes Prediction Challenge" / "test.csv")

# DISPLAY DATA
print("Train shape, test shape:")
print(train.shape, test.shape)
train.head()
# Out:
# Train shape, test shape:
# (700000, 26) (300000, 25)
#    id  age  alcohol_consumption_per_week  physical_activity_minutes_per_week  \
# 0   0   31                             1                                  45
# 1   1   50                             2                                  73
# 2   2   32                             3                                 158
# 3   3   54                             3                                  77
# 4   4   54                             1                                  55
#
#    diet_score  sleep_hours_per_day  screen_time_hours_per_day   bmi  \
# 0         7.7                  6.8                        6.1  33.4
# 1         5.7                  6.5                        5.8  23.8
# 2         8.5                  7.4                        9.1  24.1
# 3         4.6                  7.0                        9.2  26.6
# 4         5.7                  6.2                        5.1  28.8
#
#    waist_to_hip_ratio  systolic_bp  ...  gender  ethnicity  education_level  \
# 0                0.93          112  ...  Female   Hispanic       Highschool
# 1                0.83          120  ...  Female      White       Highschool
# 2                0.83           95  ...    Male   Hispanic       Highschool
# 3                0.83          121  ...  Female      White       Highschool
# 4                0.90          108  ...    Male      White       Highschool
#
#    income_level  smoking_status  employment_status family_history_diabetes  \
# 0  Lower-Middle         Current           Employed                       0
# 1  Upper-Middle           Never           Employed                       0
# 2  Lower-Middle           Never            Retired                       0
# 3  Lower-Middle         Current           Employed                       0
# 4  Upper-Middle           Never            Retired                       0
#
#   hypertension_history cardiovascular_history diagnosed_diabetes
# 0                    0                      0                1.0
# 1                    0                      0                1.0
# 2                    0                      0                0.0
# 3                    1                      0                1.0
# 4                    1                      0                1.0
#
# [5 rows x 26 columns]

# %%
for df in [train,test]:
    df.rename(columns = ({"alcohol_consumption_per_week":"alc",'physical_activity_minutes_per_week':"activity", 'diet_score':"diet",
                          'sleep_hours_per_day': "sleep", 'screen_time_hours_per_day':"screen", 'education_level':"edu",
                           'income_level':"inc", 'smoking_status': "smoke", 'employment_status':"empl", 'family_history_diabetes': "fam_his",
                          'hypertension_history': "hyp_his", 'cardiovascular_history': "card_his", 'diagnosed_diabetes': "label"} ), inplace = True)

# %%
train.head()
# Out:
#    id  age  alc  activity  diet  sleep  screen   bmi  waist_to_hip_ratio  \
# 0   0   31    1        45   7.7    6.8     6.1  33.4                0.93
# 1   1   50    2        73   5.7    6.5     5.8  23.8                0.83
# 2   2   32    3       158   8.5    7.4     9.1  24.1                0.83
# 3   3   54    3        77   4.6    7.0     9.2  26.6                0.83
# 4   4   54    1        55   5.7    6.2     5.1  28.8                0.90
#
#    systolic_bp  ...  gender  ethnicity         edu           inc    smoke  \
# 0          112  ...  Female   Hispanic  Highschool  Lower-Middle  Current
# 1          120  ...  Female      White  Highschool  Upper-Middle    Never
# 2           95  ...    Male   Hispanic  Highschool  Lower-Middle    Never
# 3          121  ...  Female      White  Highschool  Lower-Middle  Current
# 4          108  ...    Male      White  Highschool  Upper-Middle    Never
#
#        empl fam_his hyp_his card_his label
# 0  Employed       0       0        0   1.0
# 1  Employed       0       0        0   1.0
# 2   Retired       0       0        0   0.0
# 3  Employed       0       1        0   1.0
# 4   Retired       0       1        0   1.0
#
# [5 rows x 26 columns]

# %%
train.columns
# Out:
# Index(['id', 'age', 'alc', 'activity', 'diet', 'sleep', 'screen', 'bmi',
#        'waist_to_hip_ratio', 'systolic_bp', 'diastolic_bp', 'heart_rate',
#        'cholesterol_total', 'hdl_cholesterol', 'ldl_cholesterol',
#        'triglycerides', 'gender', 'ethnicity', 'edu', 'inc', 'smoke', 'empl',
#        'fam_his', 'hyp_his', 'card_his', 'label'],
#       dtype='object')

# %%
FEATURES = ['age','activity','diet','sleep','screen','bmi',
    'waist_to_hip_ratio','systolic_bp','diastolic_bp',
    'heart_rate','cholesterol_total','hdl_cholesterol',
    'ldl_cholesterol','triglycerides']
TARGET = "label"

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input, Embedding
from tensorflow.keras.layers import BatchNormalization, Dropout
from tensorflow.keras.layers import Activation
import tensorflow.keras.backend as K

print('TF Version',tf.__version__)
# Out:
# C:\ML_Projects\kaggle-workflow\venv\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):
# TF Version 2.20.0

# %%
def build_model(size):
    x_in = Input(shape=(size,))

    x = Dense(32)(x_in)
    x = BatchNormalization()(x)
    x = Activation("swish")(x)

    x = Dense(64)(x)
    x = BatchNormalization()(x)
    x = Activation("swish")(x)

    x = Dense(32)(x)
    x = BatchNormalization()(x)
    x = Activation("swish")(x)

    # Binary classification → sigmoid
    x = Dense(1, activation="sigmoid")(x)

    model = Model(inputs = x_in, outputs = x)
    return model

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.callbacks import EarlyStopping
def make_callbacks():
    lr_callback = ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.5,
        patience=3,
        verbose=1,
        min_lr=1e-6
    )

    early_stop_cb = EarlyStopping(
        monitor="val_loss",
        patience=10,
        restore_best_weights=True,
        verbose=1
    )

    return [lr_callback, early_stop_cb]

EPOCHS = 100

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score
import tensorflow.keras.backend as K

FOLDS = 5
kf = StratifiedKFold(n_splits=FOLDS, shuffle=True, random_state=42)

oof = np.zeros(len(train))
pred = np.zeros(len(test))

for i, (train_idx, valid_idx) in enumerate(kf.split(train, train[TARGET])):

    print(f"\n{'#'*28}")
    print(f"{'#'*10} Fold {i+1} {'#'*10}")
    print(f"{'#'*28}")

    # SPLIT
    X_train = train.loc[train_idx, FEATURES].copy()
    y_train = train.loc[train_idx, TARGET].values

    X_valid = train.loc[valid_idx, FEATURES].copy()
    y_valid = train.loc[valid_idx, TARGET].values

    X_test = test[FEATURES].copy()

    # NORMALIZATION (numeric only assumed)
    norm_cols = FEATURES
    means = X_train[norm_cols].mean()
    stds = X_train[norm_cols].std().replace(0, 1)

    X_train[norm_cols] = (X_train[norm_cols] - means) / stds
    X_valid[norm_cols] = (X_valid[norm_cols] - means) / stds
    X_test[norm_cols] = (X_test[norm_cols] - means) / stds

    # MODEL
    K.clear_session()
    model = build_model(X_train.shape[1])

    model.compile(
        optimizer=tf.keras.optimizers.Adam(0.001),
        loss="binary_crossentropy",
        metrics=[tf.keras.metrics.AUC(curve="ROC")]
    )

    model.fit(
        X_train, y_train,
        validation_data=(X_valid, y_valid),
        callbacks=make_callbacks(),
        batch_size=256,
        epochs=EPOCHS,
        verbose=2
    )

    # PREDICTIONS
    oof[valid_idx] = model.predict(X_valid, batch_size=512).ravel()
    pred += model.predict(X_test, batch_size=512).ravel()

    fold_auc = roc_auc_score(y_valid, oof[valid_idx])
    print(f"Fold {i+1} AUC: {fold_auc:.5f}")

pred /= FOLDS
# Out:
# ############################
# ########## Fold 1 ##########
# ############################
# WARNING:tensorflow:From C:\ML_Projects\kaggle-workflow\venv\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# Epoch 1/100
# 2188/2188 - 17s - 8ms/step - auc: 0.6458 - loss: 0.6305 - val_auc: 0.6530 - val_loss: 0.6264 - learning_rate: 0.0010
# Epoch 2/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6509 - loss: 0.6276 - val_auc: 0.6529 - val_loss: 0.6262 - learning_rate: 0.0010
# Epoch 3/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6518 - loss: 0.6271 - val_auc: 0.6538 - val_loss: 0.6257 - learning_rate: 0.0010
# Epoch 4/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6523 - loss: 0.6268 - val_auc: 0.6536 - val_loss: 0.6261 - learning_rate: 0.0010
# Epoch 5/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6525 - loss: 0.6267 - val_auc: 0.6535 - val_loss: 0.6259 - learning_rate: 0.0010
# Epoch 6/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6530 - loss: 0.6265 - val_auc: 0.6544 - val_loss: 0.6255 - learning_rate: 0.0010
# Epoch 7/100
# 2188/2188 - 21s - 9ms/step - auc: 0.6530 - loss: 0.6264 - val_auc: 0.6543 - val_loss: 0.6254 - learning_rate: 0.0010
# Epoch 8/100
# 2188/2188 - 20s - 9ms/step - auc: 0.6533 - loss: 0.6262 - val_auc: 0.6544 - val_loss: 0.6258 - learning_rate: 0.0010
# Epoch 9/100
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 2188/2188 - 12s - 5ms/step - auc: 0.6533 - loss: 0.6262 - val_auc: 0.6545 - val_loss: 0.6257 - learning_rate: 0.0010
# Epoch 10/100
# 2188/2188 - 12s - 6ms/step - auc: 0.6540 - loss: 0.6259 - val_auc: 0.6548 - val_loss: 0.6252 - learning_rate: 5.0000e-04
# Epoch 11/100
# 2188/2188 - 23s - 10ms/step - auc: 0.6542 - loss: 0.6257 - val_auc: 0.6545 - val_loss: 0.6254 - learning_rate: 5.0000e-04
# Epoch 12/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6543 - loss: 0.6257 - val_auc: 0.6546 - val_loss: 0.6253 - learning_rate: 5.0000e-04
# Epoch 13/100
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 2188/2188 - 11s - 5ms/step - auc: 0.6545 - loss: 0.6256 - val_auc: 0.6546 - val_loss: 0.6253 - learning_rate: 5.0000e-04
# Epoch 14/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6548 - loss: 0.6254 - val_auc: 0.6546 - val_loss: 0.6253 - learning_rate: 2.5000e-04
# Epoch 15/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6549 - loss: 0.6254 - val_auc: 0.6548 - val_loss: 0.6251 - learning_rate: 2.5000e-04
# Epoch 16/100
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 2188/2188 - 11s - 5ms/step - auc: 0.6548 - loss: 0.6254 - val_auc: 0.6548 - val_loss: 0.6253 - learning_rate: 2.5000e-04
# Epoch 17/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6552 - loss: 0.6251 - val_auc: 0.6548 - val_loss: 0.6252 - learning_rate: 1.2500e-04
# Epoch 18/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6551 - loss: 0.6252 - val_auc: 0.6546 - val_loss: 0.6253 - learning_rate: 1.2500e-04
# Epoch 19/100
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 2188/2188 - 9s - 4ms/step - auc: 0.6552 - loss: 0.6251 - val_auc: 0.6547 - val_loss: 0.6253 - learning_rate: 1.2500e-04
# Epoch 20/100
# 2188/2188 - 12s - 5ms/step - auc: 0.6554 - loss: 0.6250 - val_auc: 0.6548 - val_loss: 0.6253 - learning_rate: 6.2500e-05
# Epoch 21/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6554 - loss: 0.6250 - val_auc: 0.6548 - val_loss: 0.6252 - learning_rate: 6.2500e-05
# Epoch 22/100
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 2188/2188 - 11s - 5ms/step - auc: 0.6552 - loss: 0.6251 - val_auc: 0.6548 - val_loss: 0.6252 - learning_rate: 6.2500e-05
# Epoch 23/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6555 - loss: 0.6250 - val_auc: 0.6547 - val_loss: 0.6252 - learning_rate: 3.1250e-05
# Epoch 24/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6555 - loss: 0.6250 - val_auc: 0.6547 - val_loss: 0.6252 - learning_rate: 3.1250e-05
# Epoch 25/100
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 2188/2188 - 11s - 5ms/step - auc: 0.6555 - loss: 0.6250 - val_auc: 0.6548 - val_loss: 0.6252 - learning_rate: 3.1250e-05
# Epoch 25: early stopping
# Restoring model weights from the end of the best epoch: 15.
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# Fold 1 AUC: 0.65490
#
# ############################
# ########## Fold 2 ##########
# ############################
# Epoch 1/100
# 2188/2188 - 15s - 7ms/step - auc: 0.6443 - loss: 0.6312 - val_auc: 0.6522 - val_loss: 0.6270 - learning_rate: 0.0010
# Epoch 2/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6506 - loss: 0.6276 - val_auc: 0.6527 - val_loss: 0.6267 - learning_rate: 0.0010
# Epoch 3/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6517 - loss: 0.6271 - val_auc: 0.6529 - val_loss: 0.6264 - learning_rate: 0.0010
# Epoch 4/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6521 - loss: 0.6268 - val_auc: 0.6538 - val_loss: 0.6261 - learning_rate: 0.0010
# Epoch 5/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6524 - loss: 0.6267 - val_auc: 0.6542 - val_loss: 0.6258 - learning_rate: 0.0010
# Epoch 6/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6527 - loss: 0.6265 - val_auc: 0.6543 - val_loss: 0.6259 - learning_rate: 0.0010
# Epoch 7/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6530 - loss: 0.6263 - val_auc: 0.6542 - val_loss: 0.6260 - learning_rate: 0.0010
# Epoch 8/100
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 2188/2188 - 11s - 5ms/step - auc: 0.6530 - loss: 0.6263 - val_auc: 0.6537 - val_loss: 0.6260 - learning_rate: 0.0010
# Epoch 9/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6538 - loss: 0.6259 - val_auc: 0.6546 - val_loss: 0.6255 - learning_rate: 5.0000e-04
# Epoch 10/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6541 - loss: 0.6257 - val_auc: 0.6545 - val_loss: 0.6257 - learning_rate: 5.0000e-04
# Epoch 11/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6541 - loss: 0.6257 - val_auc: 0.6544 - val_loss: 0.6256 - learning_rate: 5.0000e-04
# Epoch 12/100
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 2188/2188 - 11s - 5ms/step - auc: 0.6542 - loss: 0.6257 - val_auc: 0.6546 - val_loss: 0.6256 - learning_rate: 5.0000e-04
# Epoch 13/100
# 2188/2188 - 21s - 9ms/step - auc: 0.6547 - loss: 0.6254 - val_auc: 0.6546 - val_loss: 0.6255 - learning_rate: 2.5000e-04
# Epoch 14/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6548 - loss: 0.6253 - val_auc: 0.6546 - val_loss: 0.6255 - learning_rate: 2.5000e-04
# Epoch 15/100
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 2188/2188 - 11s - 5ms/step - auc: 0.6547 - loss: 0.6253 - val_auc: 0.6547 - val_loss: 0.6255 - learning_rate: 2.5000e-04
# Epoch 16/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6552 - loss: 0.6251 - val_auc: 0.6547 - val_loss: 0.6255 - learning_rate: 1.2500e-04
# Epoch 17/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6552 - loss: 0.6251 - val_auc: 0.6546 - val_loss: 0.6255 - learning_rate: 1.2500e-04
# Epoch 18/100
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 2188/2188 - 11s - 5ms/step - auc: 0.6552 - loss: 0.6251 - val_auc: 0.6546 - val_loss: 0.6255 - learning_rate: 1.2500e-04
# Epoch 19/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6553 - loss: 0.6250 - val_auc: 0.6546 - val_loss: 0.6255 - learning_rate: 6.2500e-05
# Epoch 20/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6555 - loss: 0.6249 - val_auc: 0.6546 - val_loss: 0.6255 - learning_rate: 6.2500e-05
# Epoch 21/100
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 2188/2188 - 11s - 5ms/step - auc: 0.6552 - loss: 0.6250 - val_auc: 0.6547 - val_loss: 0.6255 - learning_rate: 6.2500e-05
# Epoch 22/100
# 2188/2188 - 12s - 5ms/step - auc: 0.6555 - loss: 0.6249 - val_auc: 0.6547 - val_loss: 0.6255 - learning_rate: 3.1250e-05
# Epoch 23/100
# 2188/2188 - 12s - 5ms/step - auc: 0.6555 - loss: 0.6249 - val_auc: 0.6546 - val_loss: 0.6255 - learning_rate: 3.1250e-05
# Epoch 24/100
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 2188/2188 - 12s - 5ms/step - auc: 0.6555 - loss: 0.6249 - val_auc: 0.6547 - val_loss: 0.6255 - learning_rate: 3.1250e-05
# Epoch 25/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6556 - loss: 0.6249 - val_auc: 0.6546 - val_loss: 0.6255 - learning_rate: 1.5625e-05
# Epoch 26/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6555 - loss: 0.6249 - val_auc: 0.6546 - val_loss: 0.6255 - learning_rate: 1.5625e-05
# Epoch 27/100
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 2188/2188 - 11s - 5ms/step - auc: 0.6556 - loss: 0.6248 - val_auc: 0.6546 - val_loss: 0.6255 - learning_rate: 1.5625e-05
# Epoch 28/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6555 - loss: 0.6249 - val_auc: 0.6546 - val_loss: 0.6255 - learning_rate: 7.8125e-06
# Epoch 29/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6555 - loss: 0.6249 - val_auc: 0.6546 - val_loss: 0.6255 - learning_rate: 7.8125e-06
# Epoch 30/100
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 2188/2188 - 12s - 6ms/step - auc: 0.6557 - loss: 0.6248 - val_auc: 0.6546 - val_loss: 0.6255 - learning_rate: 7.8125e-06
# Epoch 31/100
# 2188/2188 - 8s - 4ms/step - auc: 0.6556 - loss: 0.6249 - val_auc: 0.6546 - val_loss: 0.6255 - learning_rate: 3.9063e-06
# Epoch 32/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6555 - loss: 0.6249 - val_auc: 0.6546 - val_loss: 0.6255 - learning_rate: 3.9063e-06
# Epoch 32: early stopping
# Restoring model weights from the end of the best epoch: 22.
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# Fold 2 AUC: 0.65470
#
# ############################
# ########## Fold 3 ##########
# ############################
# Epoch 1/100
# 2188/2188 - 16s - 7ms/step - auc: 0.6456 - loss: 0.6307 - val_auc: 0.6506 - val_loss: 0.6279 - learning_rate: 0.0010
# Epoch 2/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6512 - loss: 0.6273 - val_auc: 0.6520 - val_loss: 0.6271 - learning_rate: 0.0010
# Epoch 3/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6524 - loss: 0.6267 - val_auc: 0.6522 - val_loss: 0.6272 - learning_rate: 0.0010
# Epoch 4/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6526 - loss: 0.6266 - val_auc: 0.6509 - val_loss: 0.6276 - learning_rate: 0.0010
# Epoch 5/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6530 - loss: 0.6264 - val_auc: 0.6525 - val_loss: 0.6268 - learning_rate: 0.0010
# Epoch 6/100
# 2188/2188 - 12s - 6ms/step - auc: 0.6532 - loss: 0.6263 - val_auc: 0.6520 - val_loss: 0.6268 - learning_rate: 0.0010
# Epoch 7/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6534 - loss: 0.6262 - val_auc: 0.6527 - val_loss: 0.6265 - learning_rate: 0.0010
# Epoch 8/100
# 2188/2188 - 20s - 9ms/step - auc: 0.6535 - loss: 0.6261 - val_auc: 0.6523 - val_loss: 0.6268 - learning_rate: 0.0010
# Epoch 9/100
# 2188/2188 - 21s - 9ms/step - auc: 0.6535 - loss: 0.6260 - val_auc: 0.6527 - val_loss: 0.6266 - learning_rate: 0.0010
# Epoch 10/100
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 2188/2188 - 12s - 6ms/step - auc: 0.6539 - loss: 0.6259 - val_auc: 0.6524 - val_loss: 0.6266 - learning_rate: 0.0010
# Epoch 11/100
# 2188/2188 - 12s - 5ms/step - auc: 0.6544 - loss: 0.6256 - val_auc: 0.6530 - val_loss: 0.6264 - learning_rate: 5.0000e-04
# Epoch 12/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6548 - loss: 0.6254 - val_auc: 0.6527 - val_loss: 0.6265 - learning_rate: 5.0000e-04
# Epoch 13/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6548 - loss: 0.6253 - val_auc: 0.6529 - val_loss: 0.6263 - learning_rate: 5.0000e-04
# Epoch 14/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6549 - loss: 0.6253 - val_auc: 0.6530 - val_loss: 0.6263 - learning_rate: 5.0000e-04
# Epoch 15/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6549 - loss: 0.6253 - val_auc: 0.6527 - val_loss: 0.6265 - learning_rate: 5.0000e-04
# Epoch 16/100
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 2188/2188 - 12s - 5ms/step - auc: 0.6551 - loss: 0.6252 - val_auc: 0.6528 - val_loss: 0.6265 - learning_rate: 5.0000e-04
# Epoch 17/100
# 2188/2188 - 12s - 5ms/step - auc: 0.6555 - loss: 0.6249 - val_auc: 0.6530 - val_loss: 0.6263 - learning_rate: 2.5000e-04
# Epoch 18/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6553 - loss: 0.6250 - val_auc: 0.6531 - val_loss: 0.6263 - learning_rate: 2.5000e-04
# Epoch 19/100
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 2188/2188 - 12s - 6ms/step - auc: 0.6555 - loss: 0.6250 - val_auc: 0.6529 - val_loss: 0.6263 - learning_rate: 2.5000e-04
# Epoch 20/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6558 - loss: 0.6248 - val_auc: 0.6529 - val_loss: 0.6263 - learning_rate: 1.2500e-04
# Epoch 21/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6560 - loss: 0.6247 - val_auc: 0.6529 - val_loss: 0.6263 - learning_rate: 1.2500e-04
# Epoch 22/100
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 2188/2188 - 21s - 10ms/step - auc: 0.6559 - loss: 0.6247 - val_auc: 0.6529 - val_loss: 0.6263 - learning_rate: 1.2500e-04
# Epoch 23/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6560 - loss: 0.6247 - val_auc: 0.6529 - val_loss: 0.6263 - learning_rate: 6.2500e-05
# Epoch 24/100
# 2188/2188 - 12s - 6ms/step - auc: 0.6560 - loss: 0.6246 - val_auc: 0.6530 - val_loss: 0.6263 - learning_rate: 6.2500e-05
# Epoch 25/100
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 2188/2188 - 11s - 5ms/step - auc: 0.6561 - loss: 0.6246 - val_auc: 0.6530 - val_loss: 0.6263 - learning_rate: 6.2500e-05
# Epoch 26/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6560 - loss: 0.6246 - val_auc: 0.6530 - val_loss: 0.6263 - learning_rate: 3.1250e-05
# Epoch 27/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6559 - loss: 0.6247 - val_auc: 0.6529 - val_loss: 0.6263 - learning_rate: 3.1250e-05
# Epoch 28/100
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 2188/2188 - 11s - 5ms/step - auc: 0.6559 - loss: 0.6246 - val_auc: 0.6529 - val_loss: 0.6263 - learning_rate: 3.1250e-05
# Epoch 28: early stopping
# Restoring model weights from the end of the best epoch: 18.
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# Fold 3 AUC: 0.65309
#
# ############################
# ########## Fold 4 ##########
# ############################
# Epoch 1/100
# 2188/2188 - 16s - 8ms/step - auc: 0.6463 - loss: 0.6300 - val_auc: 0.6512 - val_loss: 0.6276 - learning_rate: 0.0010
# Epoch 2/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6519 - loss: 0.6270 - val_auc: 0.6513 - val_loss: 0.6276 - learning_rate: 0.0010
# Epoch 3/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6525 - loss: 0.6267 - val_auc: 0.6518 - val_loss: 0.6272 - learning_rate: 0.0010
# Epoch 4/100
# 2188/2188 - 9s - 4ms/step - auc: 0.6529 - loss: 0.6265 - val_auc: 0.6517 - val_loss: 0.6274 - learning_rate: 0.0010
# Epoch 5/100
# 2188/2188 - 10s - 5ms/step - auc: 0.6533 - loss: 0.6262 - val_auc: 0.6521 - val_loss: 0.6272 - learning_rate: 0.0010
# Epoch 6/100
# 2188/2188 - 12s - 5ms/step - auc: 0.6534 - loss: 0.6261 - val_auc: 0.6522 - val_loss: 0.6269 - learning_rate: 0.0010
# Epoch 7/100
# 2188/2188 - 20s - 9ms/step - auc: 0.6537 - loss: 0.6260 - val_auc: 0.6524 - val_loss: 0.6269 - learning_rate: 0.0010
# Epoch 8/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6538 - loss: 0.6259 - val_auc: 0.6520 - val_loss: 0.6268 - learning_rate: 0.0010
# Epoch 9/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6540 - loss: 0.6258 - val_auc: 0.6527 - val_loss: 0.6268 - learning_rate: 0.0010
# Epoch 10/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6542 - loss: 0.6258 - val_auc: 0.6520 - val_loss: 0.6268 - learning_rate: 0.0010
# Epoch 11/100
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 2188/2188 - 12s - 6ms/step - auc: 0.6541 - loss: 0.6257 - val_auc: 0.6524 - val_loss: 0.6271 - learning_rate: 0.0010
# Epoch 12/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6548 - loss: 0.6254 - val_auc: 0.6528 - val_loss: 0.6265 - learning_rate: 5.0000e-04
# Epoch 13/100
# 2188/2188 - 13s - 6ms/step - auc: 0.6548 - loss: 0.6253 - val_auc: 0.6530 - val_loss: 0.6264 - learning_rate: 5.0000e-04
# Epoch 14/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6551 - loss: 0.6252 - val_auc: 0.6529 - val_loss: 0.6264 - learning_rate: 5.0000e-04
# Epoch 15/100
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 2188/2188 - 21s - 9ms/step - auc: 0.6549 - loss: 0.6252 - val_auc: 0.6527 - val_loss: 0.6264 - learning_rate: 5.0000e-04
# Epoch 16/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6554 - loss: 0.6250 - val_auc: 0.6530 - val_loss: 0.6263 - learning_rate: 2.5000e-04
# Epoch 17/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6555 - loss: 0.6250 - val_auc: 0.6530 - val_loss: 0.6264 - learning_rate: 2.5000e-04
# Epoch 18/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6555 - loss: 0.6249 - val_auc: 0.6531 - val_loss: 0.6263 - learning_rate: 2.5000e-04
# Epoch 19/100
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 2188/2188 - 11s - 5ms/step - auc: 0.6556 - loss: 0.6249 - val_auc: 0.6529 - val_loss: 0.6264 - learning_rate: 2.5000e-04
# Epoch 20/100
# 2188/2188 - 21s - 9ms/step - auc: 0.6557 - loss: 0.6248 - val_auc: 0.6529 - val_loss: 0.6264 - learning_rate: 1.2500e-04
# Epoch 21/100
# 2188/2188 - 21s - 10ms/step - auc: 0.6558 - loss: 0.6248 - val_auc: 0.6530 - val_loss: 0.6264 - learning_rate: 1.2500e-04
# Epoch 22/100
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 2188/2188 - 11s - 5ms/step - auc: 0.6559 - loss: 0.6247 - val_auc: 0.6529 - val_loss: 0.6263 - learning_rate: 1.2500e-04
# Epoch 23/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6560 - loss: 0.6247 - val_auc: 0.6530 - val_loss: 0.6263 - learning_rate: 6.2500e-05
# Epoch 24/100
# 2188/2188 - 21s - 9ms/step - auc: 0.6560 - loss: 0.6246 - val_auc: 0.6529 - val_loss: 0.6263 - learning_rate: 6.2500e-05
# Epoch 25/100
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 2188/2188 - 12s - 5ms/step - auc: 0.6559 - loss: 0.6247 - val_auc: 0.6530 - val_loss: 0.6263 - learning_rate: 6.2500e-05
# Epoch 26/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6559 - loss: 0.6247 - val_auc: 0.6530 - val_loss: 0.6263 - learning_rate: 3.1250e-05
# Epoch 27/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6560 - loss: 0.6246 - val_auc: 0.6530 - val_loss: 0.6263 - learning_rate: 3.1250e-05
# Epoch 28/100
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 2188/2188 - 12s - 5ms/step - auc: 0.6560 - loss: 0.6246 - val_auc: 0.6530 - val_loss: 0.6263 - learning_rate: 3.1250e-05
# Epoch 29/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6562 - loss: 0.6245 - val_auc: 0.6529 - val_loss: 0.6263 - learning_rate: 1.5625e-05
# Epoch 30/100
# 2188/2188 - 20s - 9ms/step - auc: 0.6561 - loss: 0.6246 - val_auc: 0.6529 - val_loss: 0.6263 - learning_rate: 1.5625e-05
# Epoch 31/100
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 2188/2188 - 12s - 5ms/step - auc: 0.6559 - loss: 0.6247 - val_auc: 0.6530 - val_loss: 0.6263 - learning_rate: 1.5625e-05
# Epoch 32/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6562 - loss: 0.6245 - val_auc: 0.6529 - val_loss: 0.6263 - learning_rate: 7.8125e-06
# Epoch 33/100
# 2188/2188 - 12s - 6ms/step - auc: 0.6562 - loss: 0.6246 - val_auc: 0.6530 - val_loss: 0.6263 - learning_rate: 7.8125e-06
# Epoch 33: early stopping
# Restoring model weights from the end of the best epoch: 23.
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# Fold 4 AUC: 0.65301
#
# ############################
# ########## Fold 5 ##########
# ############################
# Epoch 1/100
# 2188/2188 - 18s - 8ms/step - auc: 0.6466 - loss: 0.6298 - val_auc: 0.6503 - val_loss: 0.6280 - learning_rate: 0.0010
# Epoch 2/100
# 2188/2188 - 12s - 5ms/step - auc: 0.6513 - loss: 0.6274 - val_auc: 0.6528 - val_loss: 0.6266 - learning_rate: 0.0010
# Epoch 3/100
# 2188/2188 - 8s - 4ms/step - auc: 0.6520 - loss: 0.6269 - val_auc: 0.6529 - val_loss: 0.6266 - learning_rate: 0.0010
# Epoch 4/100
# 2188/2188 - 12s - 5ms/step - auc: 0.6526 - loss: 0.6266 - val_auc: 0.6536 - val_loss: 0.6261 - learning_rate: 0.0010
# Epoch 5/100
# 2188/2188 - 12s - 6ms/step - auc: 0.6530 - loss: 0.6264 - val_auc: 0.6532 - val_loss: 0.6269 - learning_rate: 0.0010
# Epoch 6/100
# 2188/2188 - 19s - 9ms/step - auc: 0.6532 - loss: 0.6263 - val_auc: 0.6536 - val_loss: 0.6263 - learning_rate: 0.0010
# Epoch 7/100
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 2188/2188 - 12s - 6ms/step - auc: 0.6533 - loss: 0.6262 - val_auc: 0.6534 - val_loss: 0.6263 - learning_rate: 0.0010
# Epoch 8/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6542 - loss: 0.6257 - val_auc: 0.6539 - val_loss: 0.6259 - learning_rate: 5.0000e-04
# Epoch 9/100
# 2188/2188 - 20s - 9ms/step - auc: 0.6542 - loss: 0.6256 - val_auc: 0.6539 - val_loss: 0.6260 - learning_rate: 5.0000e-04
# Epoch 10/100
# 2188/2188 - 12s - 5ms/step - auc: 0.6545 - loss: 0.6256 - val_auc: 0.6536 - val_loss: 0.6261 - learning_rate: 5.0000e-04
# Epoch 11/100
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 2188/2188 - 11s - 5ms/step - auc: 0.6544 - loss: 0.6256 - val_auc: 0.6540 - val_loss: 0.6259 - learning_rate: 5.0000e-04
# Epoch 12/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6549 - loss: 0.6252 - val_auc: 0.6540 - val_loss: 0.6258 - learning_rate: 2.5000e-04
# Epoch 13/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6550 - loss: 0.6252 - val_auc: 0.6540 - val_loss: 0.6258 - learning_rate: 2.5000e-04
# Epoch 14/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6550 - loss: 0.6251 - val_auc: 0.6539 - val_loss: 0.6259 - learning_rate: 2.5000e-04
# Epoch 15/100
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 2188/2188 - 11s - 5ms/step - auc: 0.6551 - loss: 0.6251 - val_auc: 0.6537 - val_loss: 0.6261 - learning_rate: 2.5000e-04
# Epoch 16/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6554 - loss: 0.6250 - val_auc: 0.6539 - val_loss: 0.6259 - learning_rate: 1.2500e-04
# Epoch 17/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6556 - loss: 0.6249 - val_auc: 0.6538 - val_loss: 0.6259 - learning_rate: 1.2500e-04
# Epoch 18/100
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 2188/2188 - 11s - 5ms/step - auc: 0.6555 - loss: 0.6249 - val_auc: 0.6537 - val_loss: 0.6260 - learning_rate: 1.2500e-04
# Epoch 19/100
# 2188/2188 - 12s - 5ms/step - auc: 0.6555 - loss: 0.6249 - val_auc: 0.6538 - val_loss: 0.6259 - learning_rate: 6.2500e-05
# Epoch 20/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6557 - loss: 0.6248 - val_auc: 0.6538 - val_loss: 0.6259 - learning_rate: 6.2500e-05
# Epoch 21/100
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 2188/2188 - 11s - 5ms/step - auc: 0.6557 - loss: 0.6248 - val_auc: 0.6537 - val_loss: 0.6260 - learning_rate: 6.2500e-05
# Epoch 22/100
# 2188/2188 - 11s - 5ms/step - auc: 0.6557 - loss: 0.6248 - val_auc: 0.6538 - val_loss: 0.6260 - learning_rate: 3.1250e-05
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 12.
# 274/274 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 586/586 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# Fold 5 AUC: 0.65404

# %%
MLP_oof = oof

# %%
oof_models = pd.DataFrame({
    "id": train.index,          # or explicit ID column
    "target": train[TARGET].values,
    "oof_pred_MLP": oof
})

oof_models.head()
# Out:
#    id  target  oof_pred_MLP
# 0   0     1.0      0.608593
# 1   1     1.0      0.644023
# 2   2     0.0      0.292208
# 3   3     1.0      0.666945
# 4   4     1.0      0.748159

# %%
oof_models.to_csv("oof_predictions.csv", index=False)

# %%
test_pred_models = pd.DataFrame({
    "id": test.index,           # or explicit ID column
    "prediction_MLP": pred
})

# %%
test_pred_models.head()
# Out:
#    id  prediction_MLP
# 0   0        0.602803
# 1   1        0.642024
# 2   2        0.685453
# 3   3        0.633595
# 4   4        0.867566

# %%
test_pred_models.to_csv("test_pred_models.csv", index=False)
