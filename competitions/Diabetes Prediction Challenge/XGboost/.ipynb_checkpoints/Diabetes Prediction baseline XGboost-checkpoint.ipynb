# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import KFold, StratifiedKFold, GroupKFold
from sklearn.metrics import roc_auc_score, mean_squared_error, accuracy_score

from tqdm import tqdm

import warnings; warnings.filterwarnings('ignore')

import lightgbm as lgb
import xgboost as xgb
import catboost as cb

from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score


import matplotlib.pyplot as plt
import seaborn as sns

# %%
import random
import os

def seed_everything(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)

# %%
from pathlib import Path
DATA_PATH = Path("C:/ML_Projects/kaggle-workflow/data/")
OUTPUT_PATH = Path("C:/ML_Projects/kaggle-workflow/output/")

# General settings
SEED = 42
N_FOLDS = 5

# Metric choice placeholder
#Adjust depending on the competition
METRIC = "auc"

# %%
#Load Data
train = pd.read_csv(DATA_PATH / "Diabetes Prediction Challenge" / "train.csv")
test = pd.read_csv(DATA_PATH / "Diabetes Prediction Challenge" / "test.csv")

# %%
train.columns
# Out:
# Index(['id', 'age', 'alcohol_consumption_per_week',
#        'physical_activity_minutes_per_week', 'diet_score',
#        'sleep_hours_per_day', 'screen_time_hours_per_day', 'bmi',
#        'waist_to_hip_ratio', 'systolic_bp', 'diastolic_bp', 'heart_rate',
#        'cholesterol_total', 'hdl_cholesterol', 'ldl_cholesterol',
#        'triglycerides', 'gender', 'ethnicity', 'education_level',
#        'income_level', 'smoking_status', 'employment_status',
#        'family_history_diabetes', 'hypertension_history',
#        'cardiovascular_history', 'diagnosed_diabetes'],
#       dtype='object')

# %%
train = train.rename(columns = ({"alcohol_consumption_per_week":"alc",'physical_activity_minutes_per_week':"activity", 'diet_score':"diet",
                          'sleep_hours_per_day': "sleep", 'screen_time_hours_per_day':"screen", 'education_level':"edu",
                           'income_level':"inc", 'smoking_status': "smoke", 'employment_status':"empl", 'family_history_diabetes': "fam_his",
                          'hypertension_history': "hyp_his", 'cardiovascular_history': "card_his", 'diagnosed_diabetes': "label"} ))
test = test.rename(columns = ({"alcohol_consumption_per_week":"alc",'physical_activity_minutes_per_week':"activity", 'diet_score':"diet",
                          'sleep_hours_per_day': "sleep", 'screen_time_hours_per_day':"screen", 'education_level':"edu",
                           'income_level':"inc", 'smoking_status': "smoke", 'employment_status':"empl", 'family_history_diabetes': "fam_his",
                          'hypertension_history': "hyp_his", 'cardiovascular_history': "card_his", 'diagnosed_diabetes': "label"} ))

# %%
cat_features =['gender', 'ethnicity', 'edu', 'inc', 'smoke', 'empl']

num_features = ['age', 'activity', 'sleep', 'screen', 'bmi',
       'waist_to_hip_ratio', 'systolic_bp', 'diastolic_bp', 'heart_rate',
       'cholesterol_total', 'hdl_cholesterol', 'ldl_cholesterol',
       'triglycerides']

# %%
def add_feature_cross_terms(df, numerical_features):
    df_new = df.copy()
    
    for i in range(len(numerical_features)):
        for j in range(i + 1, len(numerical_features)):  
            feature1 = numerical_features[i]
            feature2 = numerical_features[j]
            cross_term_name = f"{feature1}_x_{feature2}"
            df_new[cross_term_name] = df_new[feature1] * df_new[feature2]
            #cross_term_name = f"{feature1}_add_{feature2}"
            #df_new[cross_term_name] = df_new[feature1] + df_new[feature2]
            #cross_term_name = f"{feature1}_divided_{feature2}"
            #df_new[cross_term_name] = df_new[feature1] / df_new[feature2]

    return df_new

train = add_feature_cross_terms(train, num_features)
test = add_feature_cross_terms(test, num_features)

# %%
train.head()
# Out:
#    id  age  alc  activity  diet  sleep  screen   bmi  waist_to_hip_ratio  \
# 0   0   31    1        45   7.7    6.8     6.1  33.4                0.93
# 1   1   50    2        73   5.7    6.5     5.8  23.8                0.83
# 2   2   32    3       158   8.5    7.4     9.1  24.1                0.83
# 3   3   54    3        77   4.6    7.0     9.2  26.6                0.83
# 4   4   54    1        55   5.7    6.2     5.1  28.8                0.90
#
#    systolic_bp  ...  heart_rate_x_cholesterol_total  \
# 0          112  ...                           12338
# 1          120  ...                           14129
# 2           95  ...                           13724
# 3          121  ...                           13468
# 4          108  ...                           17510
#
#    heart_rate_x_hdl_cholesterol  heart_rate_x_ldl_cholesterol  \
# 0                          3596                          7068
# 1                          3550                          8591
# 2                          4307                          8322
# 3                          3996                          6290
# 4                          4165                         11135
#
#    heart_rate_x_triglycerides  cholesterol_total_x_hdl_cholesterol  \
# 0                        6324                                11542
# 1                        8804                                 9950
# 2                        7884                                11092
# 3                        9102                                 9828
# 4                       10540                                10094
#
#    cholesterol_total_x_ldl_cholesterol cholesterol_total_x_triglycerides  \
# 0                                22686                             20298
# 1                                24079                             24676
# 2                                21432                             20304
# 3                                15470                             22386
# 4                                26986                             25544
#
#   hdl_cholesterol_x_ldl_cholesterol hdl_cholesterol_x_triglycerides  \
# 0                              6612                            5916
# 1                              6050                            6200
# 2                              6726                            6372
# 3                              4590                            6642
# 4                              6419                            6076
#
#   ldl_cholesterol_x_triglycerides
# 0                           11628
# 1                           15004
# 2                           12312
# 3                           10455
# 4                           16244
#
# [5 rows x 104 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

for feature in cat_features:
    train[feature] = le.fit_transform(train[feature])
    test[feature] = le.transform(test[feature])
    train[feature] = train[feature].astype("category")
    test[feature] = test[feature].astype("category")
X = train.drop(columns=["id", "label"])
y = train["label"]
X_test = test.drop(columns=["id"])

# %%
train.describe()
# Out:
#                   id            age            alc       activity  \
# count  700000.000000  700000.000000  700000.000000  700000.000000
# mean   349999.500000      50.359734       2.072411      80.230803
# std    202072.738554      11.655520       1.048189      51.195071
# min         0.000000      19.000000       1.000000       1.000000
# 25%    174999.750000      42.000000       1.000000      49.000000
# 50%    349999.500000      50.000000       2.000000      71.000000
# 75%    524999.250000      58.000000       3.000000      96.000000
# max    699999.000000      89.000000       9.000000     747.000000
#
#                 diet          sleep         screen            bmi  \
# count  700000.000000  700000.000000  700000.000000  700000.000000
# mean        5.963695       7.002200       6.012733      25.874684
# std         1.463336       0.901907       2.022707       2.860705
# min         0.100000       3.100000       0.600000      15.100000
# 25%         5.000000       6.400000       4.600000      23.900000
# 50%         6.000000       7.000000       6.000000      25.900000
# 75%         7.000000       7.600000       7.400000      27.800000
# max         9.900000       9.900000      16.500000      38.400000
#
#        waist_to_hip_ratio    systolic_bp  ...  heart_rate_x_cholesterol_total  \
# count       700000.000000  700000.000000  ...                   700000.000000
# mean             0.858766     116.294193  ...                    13108.412849
# std              0.037980      11.010390  ...                     1750.833871
# min              0.680000      91.000000  ...                     6390.000000
# 25%              0.830000     108.000000  ...                    11899.000000
# 50%              0.860000     116.000000  ...                    13041.000000
# 75%              0.880000     124.000000  ...                    14271.000000
# max              1.050000     163.000000  ...                    22506.000000
#
#        heart_rate_x_hdl_cholesterol  heart_rate_x_ldl_cholesterol  \
# count                 700000.000000                 700000.000000
# mean                    3775.896107                   7221.433729
# std                      688.167484                   1523.457735
# min                     1272.000000                   2597.000000
# 25%                     3294.000000                   6142.000000
# 50%                     3752.000000                   7140.000000
# 75%                     4224.000000                   8216.000000
# max                     7410.000000                  16095.000000
#
#        heart_rate_x_triglycerides  cholesterol_total_x_hdl_cholesterol  \
# count               700000.000000                        700000.000000
# mean                  8636.695153                         10062.797610
# std                   1943.083298                          1836.719647
# min                   1581.000000                          3450.000000
# 25%                   7300.000000                          8789.000000
# 50%                   8540.000000                          9990.000000
# 75%                   9860.000000                         11256.000000
# max                  23838.000000                         19250.000000
#
#        cholesterol_total_x_ldl_cholesterol  cholesterol_total_x_triglycerides  \
# count                        700000.000000                      700000.000000
# mean                          19481.237150                       23035.739781
# std                            5090.441524                        5276.002274
# min                            6201.000000                        4191.000000
# 25%                           15648.000000                       19425.000000
# 50%                           19153.000000                       22742.000000
# 75%                           22920.000000                       26312.000000
# max                           59245.000000                       73392.000000
#
#        hdl_cholesterol_x_ldl_cholesterol  hdl_cholesterol_x_triglycerides  \
# count                      700000.000000                    700000.000000
# mean                         5479.630861                      6605.176987
# std                          1065.566146                      1609.864825
# min                          2028.000000                      1221.000000
# 25%                          4717.000000                      5488.000000
# 50%                          5418.000000                      6496.000000
# 75%                          6200.000000                      7605.000000
# max                         12530.000000                     17424.000000
#
#        ldl_cholesterol_x_triglycerides
# count                    700000.000000
# mean                      12727.653067
# std                        3728.892534
# min                        1815.000000
# 25%                       10100.000000
# 50%                       12384.000000
# 75%                       14994.000000
# max                       54210.000000
#
# [8 rows x 98 columns]

# %%
import time
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score
from xgboost import XGBClassifier

# %%
# %%time
FOLDS = 5
FEATURES = train.columns.tolist()

skf = StratifiedKFold(n_splits=FOLDS, shuffle=True, random_state=42)

oof = np.zeros(len(train))
pred = np.zeros(len(test))

for i, (train_idx, valid_idx) in enumerate(skf.split(X, y)):
    print(f"\n########## Fold {i+1} ##########")

    X_train = X.iloc[train_idx].copy()
    y_train = y.iloc[train_idx]

    X_valid = X.iloc[valid_idx].copy()
    y_valid = y.iloc[valid_idx]
    x_test = X_test.copy()

    start = time.time()

    model = XGBClassifier(
        tree_method="hist",          # switch to "hist" if no GPU
        max_depth=6,
        min_child_weight=5,
        colsample_bytree=0.8,
        subsample=0.8,
        n_estimators=2000,
        learning_rate=0.03,
        gamma=0.0,
        reg_lambda=1.0,
        objective="binary:logistic",
        eval_metric="auc",
        random_state=42,
        early_stopping_rounds=100,
        enable_categorical=True
    )

    model.fit(
        X_train, y_train,
        eval_set=[(X_valid, y_valid)],
        verbose=100
    )

    oof[valid_idx] = model.predict_proba(X_valid)[:, 1]
    pred += model.predict_proba(X_test)[:, 1]

    fold_auc = roc_auc_score(y_valid, oof[valid_idx])
    print(f"Fold {i+1} AUC: {fold_auc:.5f}")
    print(f"Time: {time.time() - start:.1f} sec")

pred /= FOLDS

cv_auc = roc_auc_score(y, oof)
print(f"\nFinal CV AUC: {cv_auc:.5f}")
# Out:
# ########## Fold 1 ##########
# [0]	validation_0-auc:0.68903
# [100]	validation_0-auc:0.70708
# [200]	validation_0-auc:0.71416
# [300]	validation_0-auc:0.71805
# [400]	validation_0-auc:0.72090
# [500]	validation_0-auc:0.72198
# [600]	validation_0-auc:0.72281
# [700]	validation_0-auc:0.72324
# [800]	validation_0-auc:0.72352
# [900]	validation_0-auc:0.72396
# [1000]	validation_0-auc:0.72429
# [1100]	validation_0-auc:0.72444
# [1200]	validation_0-auc:0.72450
# [1237]	validation_0-auc:0.72454
# Fold 1 AUC: 0.72457
# Time: 123.6 sec
#
# ########## Fold 2 ##########
# [0]	validation_0-auc:0.68690
# [100]	validation_0-auc:0.70557
# [200]	validation_0-auc:0.71187
# [300]	validation_0-auc:0.71615
# [400]	validation_0-auc:0.71867
# [500]	validation_0-auc:0.72007
# [600]	validation_0-auc:0.72083
# [700]	validation_0-auc:0.72140
# [800]	validation_0-auc:0.72191
# [900]	validation_0-auc:0.72227
# [1000]	validation_0-auc:0.72258
# [1100]	validation_0-auc:0.72274
# [1200]	validation_0-auc:0.72289
# [1300]	validation_0-auc:0.72299
# [1341]	validation_0-auc:0.72299
# Fold 2 AUC: 0.72300
# Time: 138.3 sec
#
# ########## Fold 3 ##########
# [0]	validation_0-auc:0.68584
# [100]	validation_0-auc:0.70537
# [200]	validation_0-auc:0.71267
# [300]	validation_0-auc:0.71582
# [400]	validation_0-auc:0.71867
# [500]	validation_0-auc:0.72014
# [600]	validation_0-auc:0.72138
# [700]	validation_0-auc:0.72196
# [800]	validation_0-auc:0.72261
# [900]	validation_0-auc:0.72287
# [1000]	validation_0-auc:0.72312
# [1100]	validation_0-auc:0.72329
# [1200]	validation_0-auc:0.72340
# [1300]	validation_0-auc:0.72356
# [1400]	validation_0-auc:0.72363
# [1500]	validation_0-auc:0.72371
# [1600]	validation_0-auc:0.72380
# [1700]	validation_0-auc:0.72386
# [1778]	validation_0-auc:0.72383
# Fold 3 AUC: 0.72388
# Time: 252.0 sec
#
# ########## Fold 4 ##########
# [0]	validation_0-auc:0.68801
# [100]	validation_0-auc:0.70715
# [200]	validation_0-auc:0.71464
# [300]	validation_0-auc:0.71832
# [400]	validation_0-auc:0.72065
# [500]	validation_0-auc:0.72201
# [600]	validation_0-auc:0.72308
# [700]	validation_0-auc:0.72360
# [800]	validation_0-auc:0.72406
# [900]	validation_0-auc:0.72437
# [1000]	validation_0-auc:0.72465
# [1100]	validation_0-auc:0.72481
# [1200]	validation_0-auc:0.72493
# [1260]	validation_0-auc:0.72497
# Fold 4 AUC: 0.72497
# Time: 204.7 sec
#
# ########## Fold 5 ##########
# [0]	validation_0-auc:0.68851
# [100]	validation_0-auc:0.70731
# [200]	validation_0-auc:0.71386
# [300]	validation_0-auc:0.71764
# [400]	validation_0-auc:0.72009
# [500]	validation_0-auc:0.72157
# [600]	validation_0-auc:0.72242
# [700]	validation_0-auc:0.72312
# [800]	validation_0-auc:0.72344
# [900]	validation_0-auc:0.72366
# [1000]	validation_0-auc:0.72385
# [1100]	validation_0-auc:0.72405
# [1200]	validation_0-auc:0.72419
# [1300]	validation_0-auc:0.72431
# [1400]	validation_0-auc:0.72438
# [1500]	validation_0-auc:0.72449
# [1600]	validation_0-auc:0.72462
# [1668]	validation_0-auc:0.72462
# Fold 5 AUC: 0.72465
# Time: 284.1 sec
#
# Final CV AUC: 0.72421
# CPU times: total: 2h 37min 26s
# Wall time: 16min 49s

# %%
test_preds = pred

# %%
sub = pd.read_csv(DATA_PATH / "Diabetes Prediction Challenge" / "sample_submission.csv")

# %%
sub["diagnosed_diabetes"] = test_preds
sub.head()
# Out:
#        id  diagnosed_diabetes
# 0  700000            0.514741
# 1  700001            0.685428
# 2  700002            0.776267
# 3  700003            0.408486
# 4  700004            0.937305

# %%
sub.to_csv("dia_submission_1_xgb.csv", index=False)

# %%
##CV = 0.72421, LB = 0,69513

# %%
ENS_PATH = Path("C:\ML_Projects\kaggle-workflow\competitions\Diabetes Prediction Challenge\Ens")
oof_models = pd.read_csv(ENS_PATH / "oof_predictions.csv")
oof_models.head()
# Out:
#    id  target  oof_pred_MLP  oof_pred_LGBM  oof_pred_Cat
# 0   0     1.0      0.608593       0.498156      0.470012
# 1   1     1.0      0.644023       0.592414      0.583317
# 2   2     0.0      0.292208       0.248972      0.249189
# 3   3     1.0      0.666945       0.533050      0.532701
# 4   4     1.0      0.748159       0.776689      0.763086

# %%
xgb_oof = oof

# %%
oof_models["oof_pred_xgb"] = xgb_oof
oof_models.head()
# Out:
#    id  target  oof_pred_MLP  oof_pred_LGBM  oof_pred_Cat  oof_pred_xgb
# 0   0     1.0      0.608593       0.498156      0.470012      0.526000
# 1   1     1.0      0.644023       0.592414      0.583317      0.600248
# 2   2     0.0      0.292208       0.248972      0.249189      0.204551
# 3   3     1.0      0.666945       0.533050      0.532701      0.538383
# 4   4     1.0      0.748159       0.776689      0.763086      0.757894

# %%
cor_matrix = oof_models.drop(columns = ["id", "target"]).corr()
mask = np.triu(np.ones_like(cor_matrix, dtype = "bool"))
plt.figure(figsize = (15,6))
heatmap = sns.heatmap(cor_matrix, mask = mask, annot=True, vmin = -1, vmax = 1, cmap='BrBG')
heatmap.set_title('Triangle correlation heatmap', fontdict={'fontsize':12}, pad=12)
# Out:
# Text(0.5, 1.0, 'Triangle correlation heatmap')
