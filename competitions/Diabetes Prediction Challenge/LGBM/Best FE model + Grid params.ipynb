# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import KFold, StratifiedKFold, GroupKFold
from sklearn.metrics import roc_auc_score, mean_squared_error, accuracy_score

from tqdm import tqdm

import warnings; warnings.filterwarnings('ignore')

import lightgbm as lgb
import xgboost as xgb
import catboost as cb

from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score


import matplotlib.pyplot as plt
import seaborn as sns

# %%
import random
import os

def seed_everything(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)

# %%
from pathlib import Path
DATA_PATH = Path("C:/ML_Projects/kaggle-workflow/data/")
OUTPUT_PATH = Path("C:/ML_Projects/kaggle-workflow/output/")

# General settings
SEED = 42
N_FOLDS = 5

# Metric choice placeholder
#Adjust depending on the competition
METRIC = "auc"

# %%
#Load Data
df = pd.read_csv(DATA_PATH / "Diabetes Prediction Challenge" / "train.csv")

# %%
df.columns
# Out:
# Index(['id', 'age', 'alcohol_consumption_per_week',
#        'physical_activity_minutes_per_week', 'diet_score',
#        'sleep_hours_per_day', 'screen_time_hours_per_day', 'bmi',
#        'waist_to_hip_ratio', 'systolic_bp', 'diastolic_bp', 'heart_rate',
#        'cholesterol_total', 'hdl_cholesterol', 'ldl_cholesterol',
#        'triglycerides', 'gender', 'ethnicity', 'education_level',
#        'income_level', 'smoking_status', 'employment_status',
#        'family_history_diabetes', 'hypertension_history',
#        'cardiovascular_history', 'diagnosed_diabetes'],
#       dtype='object')

# %%
df = df.rename(columns = ({"alcohol_consumption_per_week":"alc",'physical_activity_minutes_per_week':"activity", 'diet_score':"diet",
                          'sleep_hours_per_day': "sleep", 'screen_time_hours_per_day':"screen", 'education_level':"edu",
                           'income_level':"inc", 'smoking_status': "smoke", 'employment_status':"empl", 'family_history_diabetes': "fam_his",
                          'hypertension_history': "hyp_his", 'cardiovascular_history': "card_his", 'diagnosed_diabetes': "label"} ))

# %%
# === Basic EDA ===

# Shape
print("Shape:", df.shape)

# Preview
display(df.head())

# Info
print("\nInfo:")
df.info()

# Target distribution 
print("\nTarget distribution:")
print(df["label"].value_counts(normalize=True))

# Numerical stats
print("\nNumerical summary:")
display(df.describe())

# Categorical stats (top categories)
print("\nCategorical summary:")
for col in df.select_dtypes(include=["object", "category"]).columns:
    print(f"{col}: {df[col].nunique()} unique")
# Out:
# Shape: (700000, 26)
#    id  age  alc  activity  diet  sleep  screen   bmi  waist_to_hip_ratio  \
# 0   0   31    1        45   7.7    6.8     6.1  33.4                0.93
# 1   1   50    2        73   5.7    6.5     5.8  23.8                0.83
# 2   2   32    3       158   8.5    7.4     9.1  24.1                0.83
# 3   3   54    3        77   4.6    7.0     9.2  26.6                0.83
# 4   4   54    1        55   5.7    6.2     5.1  28.8                0.90
#
#    systolic_bp  ...  gender  ethnicity         edu           inc    smoke  \
# 0          112  ...  Female   Hispanic  Highschool  Lower-Middle  Current
# 1          120  ...  Female      White  Highschool  Upper-Middle    Never
# 2           95  ...    Male   Hispanic  Highschool  Lower-Middle    Never
# 3          121  ...  Female      White  Highschool  Lower-Middle  Current
# 4          108  ...    Male      White  Highschool  Upper-Middle    Never
#
#        empl fam_his hyp_his card_his label
# 0  Employed       0       0        0   1.0
# 1  Employed       0       0        0   1.0
# 2   Retired       0       0        0   0.0
# 3  Employed       0       1        0   1.0
# 4   Retired       0       1        0   1.0
#
# [5 rows x 26 columns]
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700000 entries, 0 to 699999
# Data columns (total 26 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  700000 non-null  int64
#  1   age                 700000 non-null  int64
#  2   alc                 700000 non-null  int64
#  3   activity            700000 non-null  int64
#  4   diet                700000 non-null  float64
#  5   sleep               700000 non-null  float64
#  6   screen              700000 non-null  float64
#  7   bmi                 700000 non-null  float64
#  8   waist_to_hip_ratio  700000 non-null  float64
#  9   systolic_bp         700000 non-null  int64
#  10  diastolic_bp        700000 non-null  int64
#  11  heart_rate          700000 non-null  int64
#  12  cholesterol_total   700000 non-null  int64
#  13  hdl_cholesterol     700000 non-null  int64
#  14  ldl_cholesterol     700000 non-null  int64
#  15  triglycerides       700000 non-null  int64
#  16  gender              700000 non-null  object
#  17  ethnicity           700000 non-null  object
#  18  edu                 700000 non-null  object
#  19  inc                 700000 non-null  object
#  20  smoke               700000 non-null  object
#  21  empl                700000 non-null  object
#  22  fam_his             700000 non-null  int64
#  23  hyp_his             700000 non-null  int64
#  24  card_his            700000 non-null  int64
#  25  label               700000 non-null  float64
# dtypes: float64(6), int64(14), object(6)
# memory usage: 138.9+ MB
#
# Target distribution:
# label
# 1.0    0.623296
# 0.0    0.376704
# Name: proportion, dtype: float64
#
# Numerical summary:
#                   id            age            alc       activity  \
# count  700000.000000  700000.000000  700000.000000  700000.000000
# mean   349999.500000      50.359734       2.072411      80.230803
# std    202072.738554      11.655520       1.048189      51.195071
# min         0.000000      19.000000       1.000000       1.000000
# 25%    174999.750000      42.000000       1.000000      49.000000
# 50%    349999.500000      50.000000       2.000000      71.000000
# 75%    524999.250000      58.000000       3.000000      96.000000
# max    699999.000000      89.000000       9.000000     747.000000
#
#                 diet          sleep         screen            bmi  \
# count  700000.000000  700000.000000  700000.000000  700000.000000
# mean        5.963695       7.002200       6.012733      25.874684
# std         1.463336       0.901907       2.022707       2.860705
# min         0.100000       3.100000       0.600000      15.100000
# 25%         5.000000       6.400000       4.600000      23.900000
# 50%         6.000000       7.000000       6.000000      25.900000
# 75%         7.000000       7.600000       7.400000      27.800000
# max         9.900000       9.900000      16.500000      38.400000
#
#        waist_to_hip_ratio    systolic_bp   diastolic_bp     heart_rate  \
# count       700000.000000  700000.000000  700000.000000  700000.000000
# mean             0.858766     116.294193      75.440924      70.167749
# std              0.037980      11.010390       6.825775       6.938722
# min              0.680000      91.000000      51.000000      42.000000
# 25%              0.830000     108.000000      71.000000      65.000000
# 50%              0.860000     116.000000      75.000000      70.000000
# 75%              0.880000     124.000000      80.000000      75.000000
# max              1.050000     163.000000     104.000000     101.000000
#
#        cholesterol_total  hdl_cholesterol  ldl_cholesterol  triglycerides  \
# count      700000.000000    700000.000000    700000.000000  700000.000000
# mean          186.818801        53.823214       102.905854     123.081850
# std            16.730832         8.266545        19.022416      24.739397
# min           117.000000        21.000000        51.000000      31.000000
# 25%           175.000000        48.000000        89.000000     106.000000
# 50%           187.000000        54.000000       103.000000     123.000000
# 75%           199.000000        59.000000       116.000000     139.000000
# max           289.000000        90.000000       205.000000     290.000000
#
#              fam_his        hyp_his       card_his          label
# count  700000.000000  700000.000000  700000.000000  700000.000000
# mean        0.149401       0.181990       0.030324       0.623296
# std         0.356484       0.385837       0.171478       0.484560
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       1.000000
# 75%         0.000000       0.000000       0.000000       1.000000
# max         1.000000       1.000000       1.000000       1.000000
# Categorical summary:
# gender: 3 unique
# ethnicity: 5 unique
# edu: 4 unique
# inc: 5 unique
# smoke: 3 unique
# empl: 4 unique

# %%
df.columns
# Out:
# Index(['id', 'age', 'alc', 'activity', 'diet', 'sleep', 'screen', 'bmi',
#        'waist_to_hip_ratio', 'systolic_bp', 'diastolic_bp', 'heart_rate',
#        'cholesterol_total', 'hdl_cholesterol', 'ldl_cholesterol',
#        'triglycerides', 'gender', 'ethnicity', 'edu', 'inc', 'smoke', 'empl',
#        'fam_his', 'hyp_his', 'card_his', 'label'],
#       dtype='object')

# %%
target_col = ['label']
use_cols = ['age', 'activity', 'diet','screen', 'bmi', 'waist_to_hip_ratio', 'systolic_bp', 'heart_rate',
       'cholesterol_total', 'hdl_cholesterol', 'ldl_cholesterol',
       'triglycerides', 'gender', 'ethnicity', 'edu', 'inc', 'smoke', 'empl',
       'fam_his']
X = df[use_cols].copy()
y=df[target_col].astype(int).copy()

# %%
cat_features =['gender', 'ethnicity', 'edu', 'inc', 'smoke', 'empl']

num_features = X.select_dtypes(include=["int64","float64"]).columns

# %%
X = df[num_features]

# %%
final_num = X.columns.tolist()
final_num
# Out:
# ['age',
#  'activity',
#  'diet',
#  'screen',
#  'bmi',
#  'waist_to_hip_ratio',
#  'systolic_bp',
#  'heart_rate',
#  'cholesterol_total',
#  'hdl_cholesterol',
#  'ldl_cholesterol',
#  'triglycerides',
#  'fam_his']

# %%
X["age*activity"] = X["age"] * X["activity"]
X.head()
# Out:
#    age  activity  diet  screen   bmi  waist_to_hip_ratio  systolic_bp  \
# 0   31        45   7.7     6.1  33.4                0.93          112
# 1   50        73   5.7     5.8  23.8                0.83          120
# 2   32       158   8.5     9.1  24.1                0.83           95
# 3   54        77   4.6     9.2  26.6                0.83          121
# 4   54        55   5.7     5.1  28.8                0.90          108
#
#    heart_rate  cholesterol_total  hdl_cholesterol  ldl_cholesterol  \
# 0          62                199               58              114
# 1          71                199               50              121
# 2          73                188               59              114
# 3          74                182               54               85
# 4          85                206               49              131
#
#    triglycerides  fam_his  age*activity
# 0            102        0          1395
# 1            124        0          3650
# 2            108        0          5056
# 3            123        0          4158
# 4            124        0          2970

# %%
final_cols = X.columns.tolist()
final_cols
# Out:
# ['age',
#  'activity',
#  'diet',
#  'screen',
#  'bmi',
#  'waist_to_hip_ratio',
#  'systolic_bp',
#  'heart_rate',
#  'cholesterol_total',
#  'hdl_cholesterol',
#  'ldl_cholesterol',
#  'triglycerides',
#  'fam_his',
#  'age*activity']

# %%
model = LGBMClassifier(
        n_estimators=500,
        learning_rate=0.03,
        num_leaves=31,
        min_data_in_leaf = 20,
        max_depth=-1,
        subsample=0.6,
        colsample_bytree=0.6,
        random_state=42,
        n_jobs=-1,
        verbosity = -1
    )

# %%
kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
oof = np.zeros(len(X))

for train_idx, val_idx in kf.split(X, y):
    X_tr, X_va = X.iloc[train_idx], X.iloc[val_idx]
    y_tr, y_va = y.iloc[train_idx], y.iloc[val_idx]

    model = LGBMClassifier(
        n_estimators=500,
        learning_rate=0.03,
        num_leaves=31,
        min_data_in_leaf = 20,
        max_depth=-1,
        subsample=0.6,
        colsample_bytree=0.6,
        random_state=42,
        n_jobs=-1,
        verbosity = -1
    )

    model.fit(X_tr, y_tr)
    oof[val_idx] = model.predict_proba(X_va)[:,1]

# %%
cv_auc = roc_auc_score(y, oof)
cv_auc
# Out:
# 0.7247140061679183

# %%
from sklearn.base import clone
final_model = clone(model)
final_model.fit(X,y)
# Out:
# LGBMClassifier(colsample_bytree=0.6, learning_rate=0.03, min_data_in_leaf=20,
#                n_estimators=500, n_jobs=-1, random_state=42, subsample=0.6,
#                verbosity=-1)

# %%
df_test = pd.read_csv(DATA_PATH / "Diabetes Prediction Challenge" / "test.csv")

# %%
df_test = df_test.rename(columns = ({"alcohol_consumption_per_week":"alc",'physical_activity_minutes_per_week':"activity", 'diet_score':"diet",
                          'sleep_hours_per_day': "sleep", 'screen_time_hours_per_day':"screen", 'education_level':"edu",
                           'income_level':"inc", 'smoking_status': "smoke", 'employment_status':"empl", 'family_history_diabetes': "fam_his",
                          'hypertension_history': "hyp_his", 'cardiovascular_history': "card_his", 'diagnosed_diabetes': "label"} ))

# %%
# Shape
print("Shape:", df_test.shape)

# Preview
display(df_test.head())

# Info
print("\nInfo:")
df_test.info()

# Numerical stats
print("\nNumerical summary:")
display(df_test.describe())
# Out:
# Shape: (300000, 25)
#        id  age  alc  activity  diet  sleep  screen   bmi  waist_to_hip_ratio  \
# 0  700000   45    4       100   4.3    6.8     6.2  25.5                0.84
# 1  700001   35    1        87   3.5    4.6     9.0  28.6                0.88
# 2  700002   45    1        61   7.6    6.8     7.0  28.5                0.94
# 3  700003   55    2        81   7.3    7.3     5.0  26.9                0.91
# 4  700004   77    2        29   7.3    7.6     8.5  22.0                0.83
#
#    systolic_bp  ...  triglycerides  gender  ethnicity         edu     inc  \
# 0          123  ...            111  Female      White  Highschool  Middle
# 1          120  ...            145  Female      White  Highschool  Middle
# 2          112  ...            184    Male      White  Highschool     Low
# 3          114  ...            128    Male      White    Graduate  Middle
# 4          131  ...            133    Male      White    Graduate     Low
#
#      smoke        empl fam_his hyp_his card_his
# 0   Former    Employed       0       0        0
# 1    Never  Unemployed       0       0        0
# 2    Never    Employed       0       0        0
# 3   Former    Employed       0       0        0
# 4  Current  Unemployed       0       0        0
#
# [5 rows x 25 columns]
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 25 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  300000 non-null  int64
#  1   age                 300000 non-null  int64
#  2   alc                 300000 non-null  int64
#  3   activity            300000 non-null  int64
#  4   diet                300000 non-null  float64
#  5   sleep               300000 non-null  float64
#  6   screen              300000 non-null  float64
#  7   bmi                 300000 non-null  float64
#  8   waist_to_hip_ratio  300000 non-null  float64
#  9   systolic_bp         300000 non-null  int64
#  10  diastolic_bp        300000 non-null  int64
#  11  heart_rate          300000 non-null  int64
#  12  cholesterol_total   300000 non-null  int64
#  13  hdl_cholesterol     300000 non-null  int64
#  14  ldl_cholesterol     300000 non-null  int64
#  15  triglycerides       300000 non-null  int64
#  16  gender              300000 non-null  object
#  17  ethnicity           300000 non-null  object
#  18  edu                 300000 non-null  object
#  19  inc                 300000 non-null  object
#  20  smoke               300000 non-null  object
#  21  empl                300000 non-null  object
#  22  fam_his             300000 non-null  int64
#  23  hyp_his             300000 non-null  int64
#  24  card_his            300000 non-null  int64
# dtypes: float64(5), int64(14), object(6)
# memory usage: 57.2+ MB
#
# Numerical summary:
#                   id            age            alc       activity  \
# count  300000.000000  300000.000000  300000.000000  300000.000000
# mean   849999.500000      50.432397       2.089693      92.349087
# std     86602.684716      11.938741       1.066214      62.187399
# min    700000.000000      19.000000       1.000000       1.000000
# 25%    774999.750000      42.000000       1.000000      51.000000
# 50%    849999.500000      50.000000       2.000000      77.000000
# 75%    924999.250000      59.000000       3.000000     115.000000
# max    999999.000000      89.000000       9.000000     748.000000
#
#                 diet          sleep         screen            bmi  \
# count  300000.000000  300000.000000  300000.000000  300000.000000
# mean        5.945838       6.997795       6.011278      25.881906
# std         1.481068       0.914693       2.060472       2.894289
# min         0.100000       3.100000       0.600000      15.100000
# 25%         5.000000       6.400000       4.600000      23.900000
# 50%         6.000000       7.000000       6.000000      25.900000
# 75%         7.000000       7.600000       7.400000      27.800000
# max         9.900000       9.900000      15.900000      38.300000
#
#        waist_to_hip_ratio    systolic_bp   diastolic_bp     heart_rate  \
# count       300000.000000  300000.000000  300000.000000  300000.000000
# mean             0.859007     116.374117      75.396013      70.048350
# std              0.038523      11.252146       6.950340       7.090543
# min              0.690000      91.000000      51.000000      42.000000
# 25%              0.830000     108.000000      71.000000      65.000000
# 50%              0.860000     116.000000      75.000000      70.000000
# 75%              0.890000     124.000000      80.000000      75.000000
# max              1.050000     170.000000     104.000000     101.000000
#
#        cholesterol_total  hdl_cholesterol  ldl_cholesterol  triglycerides  \
# count      300000.000000    300000.000000    300000.000000  300000.000000
# mean          187.308620        53.813557       103.416083     123.538480
# std            18.413053         8.398126        20.571855      28.965441
# min           107.000000        22.000000        51.000000      31.000000
# 25%           174.000000        48.000000        89.000000     104.000000
# 50%           187.000000        54.000000       103.000000     123.000000
# 75%           200.000000        60.000000       117.000000     142.000000
# max           285.000000        91.000000       226.000000     290.000000
#
#              fam_his        hyp_his       card_his
# count  300000.000000  300000.000000  300000.000000
# mean        0.152920       0.184410       0.033110
# std         0.359911       0.387819       0.178924
# min         0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000

# %%
df_test["age*activity"] = df_test["age"] * df_test["activity"]

# %%
X_test = df_test[final_cols]

# %%
test_preds = final_model.predict_proba(X_test)[:,1]
test_preds
# Out:
# array([0.50064778, 0.67517429, 0.75701324, ..., 0.49767055, 0.61484029,
#        0.61539393], shape=(300000,))

# %%
sub = pd.read_csv(DATA_PATH / "Diabetes Prediction Challenge" / "sample_submission.csv")

# %%
sub["diagnosed_diabetes"] = test_preds
sub.head()
# Out:
#        id  diagnosed_diabetes
# 0  700000            0.500648
# 1  700001            0.675174
# 2  700002            0.757013
# 3  700003            0.418005
# 4  700004            0.899678

# %%
#sub.to_csv("dia_submission_9.csv", index=False)

# %%
## CV = 0.7247140061679183, LB = 0.69698

# %%
nina =  pd.read_csv(DATA_PATH / "Diabetes Prediction Challenge" / "Nina.csv")
nina.rename(columns = ({"alcohol_consumption_per_week":"alc",'physical_activity_minutes_per_week':"activity", 'diet_score':"diet",
                          'sleep_hours_per_day': "sleep", 'screen_time_hours_per_day':"screen", 'education_level':"edu",
                           'income_level':"inc", 'smoking_status': "smoke", 'employment_status':"empl", 'family_history_diabetes': "fam_his",
                          'hypertension_history': "hyp_his", 'cardiovascular_history': "card_his", 'diagnosed_diabetes': "label"} ), inplace = True)
nina["age*activity"] = nina["age"] * nina["activity"]
nina = nina[final_cols]

# %%
nina_pred = final_model.predict_proba(nina)[:,1]
nina_pred
# Out:
# array([0.35495342])

# %%
ENS_PATH = Path("C:\ML_Projects\kaggle-workflow\competitions\Diabetes Prediction Challenge\Ens")
test_pred_models = pd.read_csv(ENS_PATH / "test_pred_models.csv")
test_pred_models.head()
# Out:
#    id  prediction_MLP
# 0   0        0.602803
# 1   1        0.642024
# 2   2        0.685453
# 3   3        0.633595
# 4   4        0.867566

# %%
test_pred_models["prediction_LGBM"] = test_preds
test_pred_models.head()
# Out:
#    id  prediction_MLP  prediction_LGBM
# 0   0        0.602803         0.500648
# 1   1        0.642024         0.675174
# 2   2        0.685453         0.757013
# 3   3        0.633595         0.418005
# 4   4        0.867566         0.899678

# %%
test_pred_models.to_csv("test_pred_models.csv", index=False)
